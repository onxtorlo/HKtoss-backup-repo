# %%
import openai
from vllm import LLM, SamplingParams
import huggingface_hub

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv('HUG_API_KEY')

# %%
huggingface_hub.login(token = api_key)
# Out:
# INFO 06-02 06:02:08 [config.py:793] This model supports multiple tasks: {'classify', 'reward', 'embed', 'generate', 'score'}. Defaulting to 'generate'.
# WARNING 06-02 06:02:08 [config.py:907] bitsandbytes quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# WARNING 06-02 06:02:08 [config.py:946] CUDA graph is not supported on BitsAndBytes 8bit yet, fallback to the eager mode.
# INFO 06-02 06:02:08 [config.py:2118] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 06-02 06:02:08 [cuda.py:87] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 6
#       3 import os
#       4 os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # GPU 0만 사용
# ...

# %%
import os
import ray

# Ray 중지 (실행 중이라면)
try:
    ray.shutdown()
except:
    pass

# 환경변수로 Ray 비활성화
os.environ["VLLM_USE_RAY"] = "0"

llm = LLM(
    model="Min-kyu/PJA_LLM_MODEL_8bit",
    tensor_parallel_size=1
)
# Out:
# INFO 06-02 06:02:35 [config.py:793] This model supports multiple tasks: {'classify', 'reward', 'embed', 'generate', 'score'}. Defaulting to 'generate'.
# WARNING 06-02 06:02:35 [config.py:907] bitsandbytes quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# WARNING 06-02 06:02:35 [config.py:946] CUDA graph is not supported on BitsAndBytes 8bit yet, fallback to the eager mode.
# INFO 06-02 06:02:35 [config.py:2118] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 06-02 06:02:35 [cuda.py:87] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 13
#      10 huggingface_hub.login(token=api_key)
#      12 # 가장 간단한 설정
# ---> 13 llm = LLM(
# ...

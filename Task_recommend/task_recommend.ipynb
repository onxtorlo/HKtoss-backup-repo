# %%
import json
import dotenv
import os
import openai

# %%
JSON_FILE_PATH = "C:\\Users\\user\\Documents\\pja_MLOps\\Task_recommend\\extracted_tasks.json"

# %%
dotenv.load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
with open(JSON_FILE_PATH, 'r', encoding='utf-8') as f:
    data = json.load(f)

data[99]
# Out:
# [{'workspaceId': 1,
#   'recommendedCategories': [{'name': '데이터 수집 및 분석',
#     'startDate': '2025-01-01T00:00:00',
#     'endDate': '2025-01-31T23:59:59',
#     'importance': 5,
#     'features': [{'name': '사용자 데이터 수집',
#       'startDate': '2025-01-02T00:00:00',
#       'endDate': '2025-01-10T23:59:59',
#       'importance': 4,
#       'actions': [{'name': '스마트폰 앱 개발',
#         'startDate': '2025-01-02T00:00:00',
#         'endDate': '2025-01-05T23:59:59',
#         'importance': 4},
#        {'name': '웨어러블 기기와 연동',
#         'startDate': '2025-01-06T00:00:00',
#         'endDate': '2025-01-08T23:59:59',
#         'importance': 3},
#        {'name': '데이터 저장소 설계',
#         'startDate': '2025-01-09T00:00:00',
#         'endDate': '2025-01-10T23:59:59',
#         'importance': 3}]},
#      {'name': '데이터 분석 알고리즘 개발',
#       'startDate': '2025-01-11T00:00:00',
#       'endDate': '2025-01-20T23:59:59',
#       'importance': 5,
#       'actions': [{'name': 'AI 모델 학습',
#         'startDate': '2025-01-11T00:00:00',
#         'endDate': '2025-01-15T23:59:59',
#         'importance': 5},
#        {'name': '데이터 전처리 스크립트 작성',
#         'startDate': '2025-01-16T00:00:00',
#         'endDate': '2025-01-18T23:59:59',
#         'importance': 4},
#        {'name': '결과 시각화 도구 개발',
#         'startDate': '2025-01-19T00:00:00',
#         'endDate': '2025-01-20T23:59:59',
#         'importance': 4}]}]},
#    {'name': '시간표 관리 기능',
#     'startDate': '2025-02-01T00:00:00',
#     'endDate': '2025-02-28T23:59:59',
#     'importance': 4,
#     'features': [{'name': '자동 시간표 생성',
#       'startDate': '2025-02-02T00:00:00',
#       'endDate': '2025-02-10T23:59:59',
#       'importance': 5,
#       'actions': [{'name': '시간대 분석 알고리즘 구현',
#         'startDate': '2025-02-02T00:00:00',
#         'endDate': '2025-02-05T23:59:59',
#         'importance': 5},
#        {'name': '사용자 맞춤형 시간표 생성',
#         'startDate': '2025-02-06T00:00:00',
#         'endDate': '2025-02-08T23:59:59',
#         'importance': 4},
#        {'name': '시간표 저장 및 관리 기능 구현',
#         'startDate': '2025-02-09T00:00:00',
#         'endDate': '2025-02-10T23:59:59',
#         'importance': 4}]},
#      {'name': '피드백 및 재조정 기능',
#       'startDate': '2025-02-11T00:00:00',
#       'endDate': '2025-02-20T23:59:59',
#       'importance': 4,
#       'actions': [{'name': '피드백 수집 기능 구현',
#         'startDate': '2025-02-11T00:00:00',
#         'endDate': '2025-02-15T23:59:59',
#         'importance': 4},
#        {'name': '시간표 재조정 알고리즘 개발',
#         'startDate': '2025-02-16T00:00:00',
#         'endDate': '2025-02-18T23:59:59',
#         'importance': 5},
#        {'name': '재조정 결과 사용자에게 알림',
#         'startDate': '2025-02-19T00:00:00',
#         'endDate': '2025-02-20T23:59:59',
#         'importance': 3}]}]},
#    {'name': '휴식 및 운동 제안 기능',
#     'startDate': '2025-03-01T00:00:00',
#     'endDate': '2025-03-15T23:59:59',
#     'importance': 3,
#     'features': [{'name': '휴식 시간 제안',
#       'startDate': '2025-03-02T00:00:00',
#       'endDate': '2025-03-05T23:59:59',
#       'importance': 3,
#       'actions': [{'name': '휴식 시간 데이터 분석',
#         'startDate': '2025-03-02T00:00:00',
#         'endDate': '2025-03-03T23:59:59',
#         'importance': 3},
#        {'name': '휴식 제안 알고리즘 개발',
#         'startDate': '2025-03-04T00:00:00',
#         'endDate': '2025-03-05T23:59:59',
#         'importance': 4},
#        {'name': '사용자 맞춤형 제안 기능 구현',
#         'startDate': '2025-03-06T00:00:00',
#         'endDate': '2025-03-07T23:59:59',
#         'importance': 3}]},
#      {'name': '운동 제안 기능',
#       'startDate': '2025-03-08T00:00:00',
#       'endDate': '2025-03-12T23:59:59',
#       'importance': 3,
#       'actions': [{'name': '운동 데이터 분석',
#         'startDate': '2025-03-08T00:00:00',
#         'endDate': '2025-03-09T23:59:59',
#         'importance': 3},
#        {'name': '운동 제안 알고리즘 개발',
#         'startDate': '2025-03-10T00:00:00',
#         'endDate': '2025-03-11T23:59:59',
#         'importance': 4},
#        {'name': '사용자 맞춤형 운동 제안 기능 구현',
#         'startDate': '2025-03-12T00:00:00',
#         'endDate': '2025-03-12T23:59:59',
#         'importance': 3}]}]}]}]

# %%
def recommand_task():
    # task 추천 변수
    task = ""

    # 현재 소속되어 있는 카테고리의 내용 read
    # 직전 단계, 직후 단계의 카테고리 내용 read
    
    # task recommend prompt -> 프로젝트 진행 단계(맥락) 파악해서 추가해야 할 작업 추천

    return task
